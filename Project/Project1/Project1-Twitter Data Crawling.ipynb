# %%
import tweepy 
import datetime
import csv
from tweepy import OAuthHandler, Stream, StreamListener

consumer_key=" "
consumer_secret=" "
access_token=" "
access_token_secret=" "
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
tweets = api.home_timeline()
for tweet in tweets:
	print (tweet.text)

# %%
startDate = datetime.datetime(2019, 10, 22, 12, 00, 00)
endDate = datetime.datetime(2019, 10, 23, 13, 00, 00)

if tweet.created_at < endDate and tweet.created_at > startDate:
    tweets.append(tweet)

# %%
the_list = []
tweet_nya = api.user_timeline(screen_name='ivanlanin', count=200,tweet_mode="extended")
startDate = datetime.datetime(2019, 10, 22, 12, 00, 00)
endDate = datetime.datetime(2019, 10, 23, 13, 00, 00)

for tweet in tweet_nya:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        the_list.append(tweet._json)

# %%
the_ls = []
csvFile = open('hashtag.csv', 'a')
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q = "#menteri",count=100,lang="id",since_id="2019-10-23").items():
    the_ls.append(tweet._json)
    csvWriter.writerow(tweet._json)

# %%
	import pandas` 
myHashtag = pandas.DataFrame(the_ls)
myHashtag
# Out:
#                           created_at                   id  \
# 0     Tue Oct 29 15:18:30 +0000 2019  1189199840493719553
# 1     Tue Oct 29 14:36:02 +0000 2019  1189189151477780481
# 2     Tue Oct 29 11:45:07 +0000 2019  1189146140492455937
# 3     Tue Oct 29 11:37:40 +0000 2019  1189144265043009536
# 4     Tue Oct 29 11:08:11 +0000 2019  1189136846179074052
# ...                              ...                  ...
# 1669  Mon Oct 21 01:04:14 +0000 2019  1186085751831715840
# 1670  Mon Oct 21 00:56:00 +0000 2019  1186083681930113024
# 1671  Mon Oct 21 00:45:16 +0000 2019  1186080980148183040
# 1672  Mon Oct 21 00:00:02 +0000 2019  1186069594189910016
# 1673  Sun Oct 20 23:53:46 +0000 2019  1186068019539111936
#
#                    id_str                                               text  \
# 0     1189199840493719553  Bukti yang berbicara nih ! Toyota diberi keper...
# 1     1189189151477780481  Opini mahasiswa hukum perihal kemendikbud + di...
# ...

# %%
#ini nomor 2 pakai input
csvFile = open('#Kamisan.csv', 'a')
csvWriter = csv.writer(csvFile)
hashtag = ('masukkan hashtag you want to cari')

for tweet in tweepy.Cursor(api.search,q = '#' + hashtag,count=100,lang="id",since_id="2019-10-23").items():                       
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])

# %%
	import pandas
myData = pandas.DataFrame(the_list)
myData

# %%
api = tweepy.API(auth)
try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")

# %%
api = tweepy.API(auth)
api.update_status('Third attempt: Hi! Im using tweepy to make this twit. Just to see those blue stuffs below. Cheer!')

# %%
api = tweepy.API(auth)
user = api.get_user("pwnnr")

print("User details:")
print(user.name)
print(user.description)
print(user.location)

print("Last 20 Followers:")
for follower in user.followers():
    print(follower.name)

# %%
api = tweepy.API(auth)
user = api.get_user("pwnnr")
api.update_status("Fourth attempt: User details:", user.name, user.description, user.location)

# %%
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#python'])
